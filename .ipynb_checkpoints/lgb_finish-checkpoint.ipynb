# %%
import os
import pandas as pd
import lightgbm as lgb
import xgboost as xgb
import numpy as np
import gc
import random
from sklearn import metrics
from scipy import sparse
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from collections import Counter
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn import preprocessing
label='finish'
os.environ["CUDA_VISIBLE_DEVICES"]='6'

# %%
lgb_model = lgb.LGBMClassifier(
    boosting_type="gbdt", num_leaves=2**12-1,
    max_depth=-1, n_estimators=10000, metric='logloss',
    learning_rate=0.05, random_state=2019, n_jobs=-1
)

# %%
score="directly_train"
best_num=6000

xgb_features=['uid','user_city','item_id','author_id','item_city','channel','music_id','did','video_duration',
              'did_finish_positive_num', 'did_finish_negative_num', 'did_finish_rate', 'did_all_cont','did_day_cont',
              'author_id_finish_positive_num', 'author_id_finish_negative_num', 'author_id_finish_rate','author_id_all_cont','author_id_day_cont',
              'item_id_finish_positive_num', 'item_id_finish_negative_num', 'item_id_finish_rate','item_id_all_cont','item_id_day_cont',
              'author_id_did_all_cont',
              'author_include_num_of_item','author_include_num_of_uid',
              'uid_num_of_author_mean','uid_num_of_author_var','uid_num_of_author_fft_var',
              'title_cont','beauty_min','uid_has_num_of_did',
                'mean_id','id_mean_differ','max_id','id_max_differ','min_id','id_min_differ',
                'title_mean_rate_finish','title_max_rate_finish','title_min_rate_finish','title_mean',  
                 'uid_channel_title_mean_mean', 'uid_channel_title_mean_std', 'uid_channel_title_mean_skew']

xgb_features+=['audio_embedding_'+str(i) for i in range(64)]+['video_embedding_'+str(i) for i in range(32)]+['author_id_embedding_'+str(i) for i in range(10)]+\
                ['uid_embedding_'+str(i) for i in range(10)]+['did_embedding_'+str(i) for i in range(10)]+\
    ['uid_deepwalk_embedding_'+str(i) for i in range(10)]+['item_id_deepwalk_embedding_'+str(i) for i in range(10)]
xgb_features+=["user_item_id_"+str(i) for i in range(32)]
#xgb_features+=["item_uid_"+str(i) for i in range(32)]
xgb_features+=["did_author_id_"+str(i) for i in range(32)]
#xgb_features+=["author_did_"+str(i) for i in range(32)] 
print(len(xgb_features),len(set(xgb_features)))
# Out:
# 256 256

# %% [markdown]
# # dev

# %%
np.random.seed(2019)
test_df=pd.read_pickle('data/dev_xgb.pkl')
print(test_df.shape)
test_y=test_df[label]
test_x=test_df[xgb_features]
del test_df
gc.collect()
# Out:
# (2803191, 417)
# 22

# %%
train_df=pd.read_pickle('data/train_dev_xgb_'+str(0)+'.pkl')
print(train_df.shape)
train_y=train_df[label]
train_x=train_df[xgb_features]
del train_df
gc.collect()

# %%
lgb_model.fit(train_x, train_y, eval_metric='auc', eval_set=[(test_x,test_y)], verbose=10, early_stopping_rounds=100)

# %% [raw]
# 208
# convert train dataset
# done!
# convert test dataset
# done!
# [0]	test-auc:0.695579
# Will train until test-auc hasn't improved in 100000 rounds.
# [10]	test-auc:0.704958
# [20]	test-auc:0.704908
# [30]	test-auc:0.706081
# [40]	test-auc:0.707184
# [50]	test-auc:0.708231
# [60]	test-auc:0.708759
# [70]	test-auc:0.70992
# [80]	test-auc:0.710592
# [90]	test-auc:0.711553
# [100]	test-auc:0.712326
# [110]	test-auc:0.713174
# [120]	test-auc:0.714029
# [130]	test-auc:0.714713
# [140]	test-auc:0.715448
# [150]	test-auc:0.716166
# [160]	test-auc:0.716732
# [170]	test-auc:0.717212
# [180]	test-auc:0.717593
# [190]	test-auc:0.718067
# [200]	test-auc:0.71848
# [210]	test-auc:0.718836
# [220]	test-auc:0.719111
# [230]	test-auc:0.719467
# [240]	test-auc:0.719775
# [250]	test-auc:0.72006
# [260]	test-auc:0.720308
# [270]	test-auc:0.720568
# [280]	test-auc:0.72085
# [290]	test-auc:0.721082
# [300]	test-auc:0.721217
# [310]	test-auc:0.72141
# [320]	test-auc:0.721626
# [330]	test-auc:0.721814
# [340]	test-auc:0.722028
# [350]	test-auc:0.72216
# [360]	test-auc:0.722364
# [370]	test-auc:0.722506
# [380]	test-auc:0.722707
# [390]	test-auc:0.722836
# [400]	test-auc:0.723102
# [410]	test-auc:0.723296
# [420]	test-auc:0.723429
# [430]	test-auc:0.723612
# [440]	test-auc:0.723724
# [450]	test-auc:0.723911
# [460]	test-auc:0.724044
# [470]	test-auc:0.724166
# [480]	test-auc:0.724279
# [490]	test-auc:0.724409
# [500]	test-auc:0.724553
# [510]	test-auc:0.724671
# [520]	test-auc:0.724786
# [530]	test-auc:0.724877
# [540]	test-auc:0.724986
# [550]	test-auc:0.725076
# [560]	test-auc:0.725175
# [570]	test-auc:0.725267
# [580]	test-auc:0.725358
# [590]	test-auc:0.725437
# [600]	test-auc:0.725519
# [610]	test-auc:0.725601
# [620]	test-auc:0.725682
# [630]	test-auc:0.72577
# [640]	test-auc:0.725848
# [650]	test-auc:0.725882
# [660]	test-auc:0.725959
# [670]	test-auc:0.726049
# [680]	test-auc:0.726107
# [690]	test-auc:0.726154
# [700]	test-auc:0.726224
# [710]	test-auc:0.726269
# [720]	test-auc:0.726366
# [730]	test-auc:0.726472
# [740]	test-auc:0.726542
# [750]	test-auc:0.726627
# [760]	test-auc:0.726706
# [770]	test-auc:0.726759
# [780]	test-auc:0.726821
# [790]	test-auc:0.726867
# [800]	test-auc:0.726921
# [810]	test-auc:0.726994
# [820]	test-auc:0.727033
# [830]	test-auc:0.727081
# [840]	test-auc:0.72716
# [850]	test-auc:0.727183
# [860]	test-auc:0.727243
# [870]	test-auc:0.727294
# [880]	test-auc:0.727362
# [890]	test-auc:0.727403
# [900]	test-auc:0.727477
# [910]	test-auc:0.727534
# [920]	test-auc:0.727581
# [930]	test-auc:0.727626
# [940]	test-auc:0.727679
# [950]	test-auc:0.727725
# [960]	test-auc:0.727812
# [970]	test-auc:0.727902
# [980]	test-auc:0.727928
# [990]	test-auc:0.727972
# [1000]	test-auc:0.727996
# [1010]	test-auc:0.728047
# [1020]	test-auc:0.728092
# [1030]	test-auc:0.728138
# [1040]	test-auc:0.728168
# [1050]	test-auc:0.728219
# [1060]	test-auc:0.728263
# [1070]	test-auc:0.728307
# [1080]	test-auc:0.728351
# [1090]	test-auc:0.728379
# [1100]	test-auc:0.72841
# [1110]	test-auc:0.728448
# [1120]	test-auc:0.728481
# [1130]	test-auc:0.728524
# [1140]	test-auc:0.728562
# [1150]	test-auc:0.728607
# [1160]	test-auc:0.72864
# [1170]	test-auc:0.728711
# [1180]	test-auc:0.728716
# [1190]	test-auc:0.728733
# [1200]	test-auc:0.728779
# [1210]	test-auc:0.728848
# [1220]	test-auc:0.728882
# [1230]	test-auc:0.728906
# [1240]	test-auc:0.728956
# [1250]	test-auc:0.729021
# [1260]	test-auc:0.729074
# [1270]	test-auc:0.729113
# [1280]	test-auc:0.729134
# [1290]	test-auc:0.729177
# [1300]	test-auc:0.729213
# [1310]	test-auc:0.729278
# [1320]	test-auc:0.729292
# [1330]	test-auc:0.729305
# [1340]	test-auc:0.72932
# [1350]	test-auc:0.72936
# [1360]	test-auc:0.729463
# [1370]	test-auc:0.729487
# [1380]	test-auc:0.729521
# [1390]	test-auc:0.72956
# [1400]	test-auc:0.729702
# [1410]	test-auc:0.729918
# [1420]	test-auc:0.729957
# [1430]	test-auc:0.730017
# [1440]	test-auc:0.730056
# [1450]	test-auc:0.730083
# [1460]	test-auc:0.730106
# [1470]	test-auc:0.73012
# [1480]	test-auc:0.730156
# [1490]	test-auc:0.730159
# [1500]	test-auc:0.730184
# [1510]	test-auc:0.730198
# [1520]	test-auc:0.730222
# [1530]	test-auc:0.730259
# [1540]	test-auc:0.730298
# [1550]	test-auc:0.730327
# [1560]	test-auc:0.730364
# [1570]	test-auc:0.730383
# [1580]	test-auc:0.730402
# [1590]	test-auc:0.730463
# [1600]	test-auc:0.730455
# [1610]	test-auc:0.730508
# [1620]	test-auc:0.730574
# [1630]	test-auc:0.730592
# [1640]	test-auc:0.730658
# [1650]	test-auc:0.730685
# [1660]	test-auc:0.730778
# [1670]	test-auc:0.730778
# [1680]	test-auc:0.730801
# [1690]	test-auc:0.730722
# [1700]	test-auc:0.730858
# [1710]	test-auc:0.730955
# [1720]	test-auc:0.731037
# [1730]	test-auc:0.731039
# [1740]	test-auc:0.731315
# [1750]	test-auc:0.73133
# [1760]	test-auc:0.731201
# [1770]	test-auc:0.731286
# [1780]	test-auc:0.731304
# [1790]	test-auc:0.73131
# [1800]	test-auc:0.731334
# [1810]	test-auc:0.731356
# [1820]	test-auc:0.731321
# [1830]	test-auc:0.73135
# [1840]	test-auc:0.731388
# [1850]	test-auc:0.73141
# [1860]	test-auc:0.73148
# [1870]	test-auc:0.731516
# [1880]	test-auc:0.731554
# [1890]	test-auc:0.731564
# [1900]	test-auc:0.731574
# [1910]	test-auc:0.731595
# [1920]	test-auc:0.731602
# [1930]	test-auc:0.731656
# [1940]	test-auc:0.731727
# [1950]	test-auc:0.73173
# [1960]	test-auc:0.731732
# [1970]	test-auc:0.731726
# [1980]	test-auc:0.731747
# [1990]	test-auc:0.731764
# [2000]	test-auc:0.731781
# [2010]	test-auc:0.731786
# [2020]	test-auc:0.731803
# [2030]	test-auc:0.731818
# [2040]	test-auc:0.731849
# [2050]	test-auc:0.731835
# [2060]	test-auc:0.731872
# [2070]	test-auc:0.731896
# [2080]	test-auc:0.731912
# [2090]	test-auc:0.731951
# [2100]	test-auc:0.731976
# [2110]	test-auc:0.731985
# [2120]	test-auc:0.732
# [2130]	test-auc:0.732005
# [2140]	test-auc:0.732163
# [2150]	test-auc:0.732181
# [2160]	test-auc:0.732217
# [2170]	test-auc:0.732223
# [2180]	test-auc:0.732231
# [2190]	test-auc:0.732237
# [2200]	test-auc:0.732272
# [2210]	test-auc:0.732297
# [2220]	test-auc:0.732309
# [2230]	test-auc:0.732344
# [2240]	test-auc:0.732369
# [2250]	test-auc:0.732393
# [2260]	test-auc:0.732422
# [2270]	test-auc:0.732466
# [2280]	test-auc:0.732505
# [2290]	test-auc:0.732512
# [2300]	test-auc:0.732584
# [2310]	test-auc:0.732592
# [2320]	test-auc:0.732608
# [2330]	test-auc:0.73262
# [2340]	test-auc:0.732681
# [2350]	test-auc:0.732715
# [2360]	test-auc:0.73273
# [2370]	test-auc:0.732759
# [2380]	test-auc:0.732763
# [2390]	test-auc:0.732771
# [2400]	test-auc:0.732782
# [2410]	test-auc:0.732804
# [2420]	test-auc:0.732818
# [2430]	test-auc:0.732924
# [2440]	test-auc:0.732988
# [2450]	test-auc:0.733021
# [2460]	test-auc:0.733031
# [2470]	test-auc:0.73304
# [2480]	test-auc:0.733027
# [2490]	test-auc:0.733302
# [2500]	test-auc:0.733371
# [2510]	test-auc:0.733387
# [2520]	test-auc:0.733418
# [2530]	test-auc:0.733435
# [2540]	test-auc:0.733454
# [2550]	test-auc:0.733463
# [2560]	test-auc:0.733485
# [2570]	test-auc:0.733487
# [2580]	test-auc:0.733505
# [2590]	test-auc:0.733521
# [2600]	test-auc:0.73354
# [2610]	test-auc:0.733577
# [2620]	test-auc:0.733611
# [2630]	test-auc:0.733645
# [2640]	test-auc:0.733653
# [2650]	test-auc:0.733693
# [2660]	test-auc:0.73369
# [2670]	test-auc:0.733699
# [2680]	test-auc:0.733711
# [2690]	test-auc:0.733719
# [2700]	test-auc:0.733739
# [2710]	test-auc:0.733755
# [2720]	test-auc:0.733899
# [2730]	test-auc:0.733945
# [2740]	test-auc:0.733947
# [2750]	test-auc:0.733958
# [2760]	test-auc:0.733961
# [2770]	test-auc:0.733975
# [2780]	test-auc:0.733983
# [2790]	test-auc:0.734014
# [2800]	test-auc:0.734032
# [2810]	test-auc:0.734044
# [2820]	test-auc:0.734056
# [2830]	test-auc:0.734071
# [2840]	test-auc:0.734073
# [2850]	test-auc:0.734083
# [2860]	test-auc:0.734093
# [2870]	test-auc:0.734112
# [2880]	test-auc:0.73412
# [2890]	test-auc:0.734133
# [2900]	test-auc:0.734141
# [2910]	test-auc:0.734174
# [2920]	test-auc:0.734195
# [2930]	test-auc:0.73421
# [2940]	test-auc:0.734218
# [2950]	test-auc:0.734223
# [2960]	test-auc:0.734242
# [2970]	test-auc:0.734239
# [2980]	test-auc:0.734243
# [2990]	test-auc:0.734252
# [3000]	test-auc:0.734274
# [3010]	test-auc:0.73429
# [3020]	test-auc:0.734318
# [3030]	test-auc:0.734325
# [3040]	test-auc:0.734323
# [3050]	test-auc:0.73436
# [3060]	test-auc:0.734377
# [3070]	test-auc:0.734425
# [3080]	test-auc:0.734424
# [3090]	test-auc:0.734453
# [3100]	test-auc:0.734464
# [3110]	test-auc:0.734481
# [3120]	test-auc:0.734487
# [3130]	test-auc:0.734496
# [3140]	test-auc:0.734539
# [3150]	test-auc:0.734579
# [3160]	test-auc:0.734585
# [3170]	test-auc:0.734619
# [3180]	test-auc:0.734643
# [3190]	test-auc:0.734661
# [3200]	test-auc:0.734701
# [3210]	test-auc:0.734718
# [3220]	test-auc:0.734729
# [3230]	test-auc:0.734736
# [3240]	test-auc:0.734769
# [3250]	test-auc:0.734781
# [3260]	test-auc:0.734831
# [3270]	test-auc:0.734833
# [3280]	test-auc:0.734835
# [3290]	test-auc:0.734852
# [3300]	test-auc:0.73486
# [3310]	test-auc:0.734865
# [3320]	test-auc:0.734885
# [3330]	test-auc:0.734881
# [3340]	test-auc:0.734878
# [3350]	test-auc:0.734877
# [3360]	test-auc:0.734885
# [3370]	test-auc:0.734888
# [3380]	test-auc:0.734883
# [3390]	test-auc:0.734888
# [3400]	test-auc:0.734901
# [3410]	test-auc:0.734914
# [3420]	test-auc:0.734927
# [3430]	test-auc:0.734939
# [3440]	test-auc:0.734952
# [3450]	test-auc:0.734953
# [3460]	test-auc:0.73496
# [3470]	test-auc:0.734954
# [3480]	test-auc:0.734952
# [3490]	test-auc:0.734945
# [3500]	test-auc:0.734963
# [3510]	test-auc:0.734971
# [3520]	test-auc:0.734975
# [3530]	test-auc:0.734973
# [3540]	test-auc:0.734982
# [3550]	test-auc:0.735001
# [3560]	test-auc:0.735013
# [3570]	test-auc:0.735046
# [3580]	test-auc:0.73506
# [3590]	test-auc:0.73507
# [3600]	test-auc:0.735079
# [3610]	test-auc:0.735093
# [3620]	test-auc:0.735105
# [3630]	test-auc:0.735222
# [3640]	test-auc:0.735295
# [3650]	test-auc:0.7353
# [3660]	test-auc:0.735306
# [3670]	test-auc:0.735332
# [3680]	test-auc:0.735339
# [3690]	test-auc:0.735353
# [3700]	test-auc:0.735368
# [3710]	test-auc:0.735378
# [3720]	test-auc:0.73541
# [3730]	test-auc:0.735417
# [3740]	test-auc:0.735422
# [3750]	test-auc:0.735427
# [3760]	test-auc:0.735487
# [3770]	test-auc:0.735528
# [3780]	test-auc:0.735576
# [3790]	test-auc:0.735583
# [3800]	test-auc:0.735552
# [3810]	test-auc:0.735563
# [3820]	test-auc:0.735584
# [3830]	test-auc:0.7356
# [3840]	test-auc:0.735609
# [3850]	test-auc:0.735618
# [3860]	test-auc:0.735628
# [3870]	test-auc:0.735626
# [3880]	test-auc:0.735675
# [3890]	test-auc:0.735684
# [3900]	test-auc:0.735684
# [3910]	test-auc:0.73569
# [3920]	test-auc:0.73569
# [3930]	test-auc:0.735671
# [3940]	test-auc:0.735684
# [3950]	test-auc:0.73569
# [3960]	test-auc:0.735695
# [3970]	test-auc:0.735699
# [3980]	test-auc:0.735711
# [3990]	test-auc:0.735723
# [4000]	test-auc:0.735732
# [4010]	test-auc:0.735749
# [4020]	test-auc:0.735753
# [4030]	test-auc:0.735783
# [4040]	test-auc:0.735783
# [4050]	test-auc:0.735791
# [4060]	test-auc:0.735805
# [4070]	test-auc:0.735826
# [4080]	test-auc:0.735832
# [4090]	test-auc:0.735836
# [4100]	test-auc:0.735853
# [4110]	test-auc:0.735861
# [4120]	test-auc:0.735852
# [4130]	test-auc:0.735861
# [4140]	test-auc:0.735867
# [4150]	test-auc:0.735872
# [4160]	test-auc:0.735874
# [4170]	test-auc:0.735875
# [4180]	test-auc:0.735881
# [4190]	test-auc:0.735821
# [4200]	test-auc:0.735825
# [4210]	test-auc:0.735834
# [4220]	test-auc:0.735807
# [4230]	test-auc:0.735801
# [4240]	test-auc:0.735799
# [4250]	test-auc:0.735801
# [4260]	test-auc:0.73582
# [4270]	test-auc:0.735824
# [4280]	test-auc:0.735861
# [4290]	test-auc:0.735867
# [4300]	test-auc:0.735886
# [4310]	test-auc:0.735896
# [4320]	test-auc:0.735912
# [4330]	test-auc:0.735919
# [4340]	test-auc:0.735912
# [4350]	test-auc:0.735921
# [4360]	test-auc:0.735933
# [4370]	test-auc:0.735939
# [4380]	test-auc:0.735949
# [4390]	test-auc:0.735952
# [4400]	test-auc:0.735961
# [4410]	test-auc:0.735938
# [4420]	test-auc:0.735943
# [4430]	test-auc:0.73597
# [4440]	test-auc:0.735979
# [4450]	test-auc:0.735982
# [4460]	test-auc:0.735988
# [4470]	test-auc:0.736013
# [4480]	test-auc:0.736001
# [4490]	test-auc:0.736009
# [4500]	test-auc:0.736012
# [4510]	test-auc:0.736024
# [4520]	test-auc:0.736038
# [4530]	test-auc:0.736041
# [4540]	test-auc:0.736142
# [4550]	test-auc:0.736145
# [4560]	test-auc:0.73615
# [4570]	test-auc:0.736153
# [4580]	test-auc:0.736169
# [4590]	test-auc:0.736172
# [4600]	test-auc:0.736186
# [4610]	test-auc:0.73619
# [4620]	test-auc:0.736406
# [4630]	test-auc:0.736406
# [4640]	test-auc:0.736418
# [4650]	test-auc:0.736338
# [4660]	test-auc:0.736343
# [4670]	test-auc:0.736355
# [4680]	test-auc:0.736371
# [4690]	test-auc:0.736379
# [4700]	test-auc:0.736385
# [4710]	test-auc:0.736389
# [4720]	test-auc:0.736373
# [4730]	test-auc:0.736377
# [4740]	test-auc:0.736411
# [4750]	test-auc:0.736424
# [4760]	test-auc:0.736414
# [4770]	test-auc:0.736416
# [4780]	test-auc:0.736413
# [4790]	test-auc:0.73642
# [4800]	test-auc:0.736423
# [4810]	test-auc:0.736476
# [4820]	test-auc:0.736456
# [4830]	test-auc:0.73646
# [4840]	test-auc:0.736463
# [4850]	test-auc:0.736523
# [4860]	test-auc:0.736527
# [4870]	test-auc:0.736528
# [4880]	test-auc:0.736528
# [4890]	test-auc:0.73653
# [4900]	test-auc:0.736562
# [4910]	test-auc:0.736567
# [4920]	test-auc:0.73657
# [4930]	test-auc:0.736571
# [4940]	test-auc:0.73658
# [4950]	test-auc:0.736585
# [4960]	test-auc:0.736587
# [4970]	test-auc:0.736595
# [4980]	test-auc:0.7366
# [4990]	test-auc:0.736601
# [4999]	test-auc:0.736608
# Dev Inference:
# finish 0.736608

# %%
print("Dev Inference:")
test_x[label+'_probability']=preds.round(6) 
fpr, tpr, thresholds = metrics.roc_curve(test_y+1, test_x[label+'_probability'], pos_label=2)
auc=metrics.auc(fpr, tpr)
score=str(round(auc,6))
print(label,score)
# Out:
# Dev Inference:
# finish 0.736562

# %%
pd.Series(model.get_fscore()).sort_values(ascending=False)
# Out:
# item_id_finish_rate              10715
# did_finish_rate                  10599
# author_id_did_all_cont            8869
# author_id_finish_rate             8857
# did_day_cont                      7635
# audio_embedding_0                 7409
# item_id_deepwalk_embedding_1      6325
# uid_channel_title_mean_skew       6303
# video_embedding_0                 6196
# item_id_deepwalk_embedding_8      6094
# item_id_deepwalk_embedding_4      6063
# user_item_id_2                    5969
# uid_deepwalk_embedding_2          5910
# item_id_deepwalk_embedding_9      5908
# user_item_id_15                   5874
# item_id_deepwalk_embedding_2      5865
# author_id_embedding_0             5815
# author_id_embedding_7             5798
# user_city                         5787
# uid_deepwalk_embedding_8          5747
# user_item_id_5                    5737
# uid_deepwalk_embedding_6          5736
# user_item_id_13                   5715
# author_id_embedding_2             5714
# ...

# %%
del model
del train_x
del train_y
del test_x
del test_y
gc.collect()
# Out:
# 34

# %%
best_num=6000
print(best_num)
# Out:
# 6000

# %% [markdown]
# # Test

# %%
score=str(round(0.736562,6))

# %%
test_df=pd.read_pickle('data/test_xgb.pkl')
train_df=pd.read_pickle('data/train_xgb_'+str(0)+'.pkl')
print(train_df.shape,test_df.shape)
gc.collect()
# Out:
# (19622340, 413) (2761799, 413)
# 0

# %%
index=set(range(train_df.shape[0]))
kfold=10
K_fold=[]
for i in range(kfold):
    if i == kfold-1:
        tmp=index
    else:
        tmp=random.sample(index,int(1.0/kfold*train_df.shape[0]))
    index=index-set(tmp)
    print("Number:",len(tmp))
    K_fold.append(tmp)
    
train_y=train_df[label]
train_df=train_df[xgb_features]
test_df=test_df[xgb_features]
gc.collect()
for i in range(kfold):
    print("Fold",i)
    train_index=[]
    for j in range(kfold):
        if j!=i:
            train_index+=K_fold[j]
    print("Number:",len(train_index))
    print("best_num",best_num)
    y_test,model,num=runXGB(train_df.iloc[train_index],train_y.iloc[train_index],test_df,seed_val=2019+i,num_rounds=best_num)
    del model
    gc.collect()    
    if i==0:
        preds=y_test/kfold
    else:
        preds+=y_test/kfold


        
test_df[label+'_probability']=preds.round(6)
print(test_df[['uid','item_id',label+'_probability']].head())
try:
    os.mkdir('submission')
except:
    pass
try:
    os.mkdir('submission/'+label)
except:
    pass
test_df[['uid','item_id',label+'_probability']].to_csv('submission/'+label+'/xgb_'+score+'.csv',index=False)
# Out:
# Number: 1962234
# Number: 1962234
# Number: 1962234
# Number: 1962234
# Number: 1962234
# Number: 1962234
# Number: 1962234
# Number: 1962234
# Number: 1962234
# Number: 1962234
# Fold 0
# Number: 17660106
# best_num 6000
# convert train dataset
# done!
# Fold 1
# Number: 17660106
# best_num 6000
# convert train dataset
# done!

# %%
print(test_df.head())
print(test_df[label+'_probability'].mean())

# %%
1
# Out:
# 1
